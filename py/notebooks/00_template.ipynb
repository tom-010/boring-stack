# %% [markdown]
# # 00 Template
#
# Describe what dies notebook does here. This notebook is a copy & paste template.
#
# ## Insights
#
# After you are done, write up your insights here to make the notebooks browsable.

# %%
NOTEBOOK_NAME = "00_template"

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

data_root = Path("./data")
data_dir = data_root / NOTEBOOK_NAME
data_dir.mkdir(exist_ok=True)

# Data Science
# import numpy as np
# np.set_printoptions(precision=4, suppress=True)
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns
# import pandas as pd
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', 100)

# 5. Deep Learning (PyTorch)
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# from torch.utils.data import Dataset, DataLoader
# device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
